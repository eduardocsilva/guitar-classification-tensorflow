# %% [markdown]
# # Guitar Classifier (powered by TensorFlow)
# #### Based on https://www.tensorflow.org/tutorials/images/classification

# %% [markdown]
# ## 1. Load Dataset

# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model

# %%
# Load Dataset
import pathlib
data_dir = pathlib.Path('images')

image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 8500

# %%
print("Here's a Les Paul")
les_pauls = list(data_dir.glob('gibson_les_paul/*'))
PIL.Image.open(str(les_pauls[0]))
# Out:
# Here's a Les Paul
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x299 at 0x7FFBCE97B8E0>

# %%
print ("Here's a Strat")
strats = list(data_dir.glob('fender_stratocaster/*'))
PIL.Image.open(str(strats[0]))
# Out:
# Here's a Strat
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x299 at 0x7FFBD5744E80>

# %% [markdown]
# ## 2. Split Dataset

# %%
# Split Dataset (Training (70%) / Test (30%))
batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 8500 files belonging to 11 classes.
# Using 6800 files for training.
# Found 8500 files belonging to 11 classes.
# Using 1700 files for validation.

# %%
# Visualize the data
import matplotlib.pyplot as plt

class_names = train_ds.class_names
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# Performance tuning/configurations
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Normalize data (between [0,1], important for neural network performance)
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]

# Now the values are in the [0,1] interval
print(np.min(first_image), np.max(first_image))
# Out:
# 0.00023269557 1.0

# %% [markdown]
# ## 4. Model Creation

# %%
num_classes = 11

# The model consists of three convolution blocks with a max pool layer in each of them. 
# There's a fully connected layer with 128 units on top of it that is activated by a relu activation function
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# Model Compilation
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_5 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               3965056
# _________________________________________________________________
# dense_7 (Dense)              (None, 11)                1419
# =================================================================
# Total params: 3,990,059
# Trainable params: 3,990,059
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. Model Training

# %%
# Model Training 
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 213/213 [==============================] - 85s 396ms/step - loss: 2.1777 - accuracy: 0.2432 - val_loss: 1.7131 - val_accuracy: 0.4271
# Epoch 2/10
# 213/213 [==============================] - 78s 366ms/step - loss: 1.3762 - accuracy: 0.5522 - val_loss: 1.3745 - val_accuracy: 0.5624
# Epoch 3/10
# 213/213 [==============================] - 77s 362ms/step - loss: 0.8173 - accuracy: 0.7328 - val_loss: 1.2147 - val_accuracy: 0.6365
# Epoch 4/10
# 213/213 [==============================] - 77s 359ms/step - loss: 0.4286 - accuracy: 0.8624 - val_loss: 1.3669 - val_accuracy: 0.6588
# Epoch 5/10
# 213/213 [==============================] - 99s 463ms/step - loss: 0.1844 - accuracy: 0.9435 - val_loss: 1.7875 - val_accuracy: 0.6659
# Epoch 6/10
# 213/213 [==============================] - 93s 435ms/step - loss: 0.0848 - accuracy: 0.9766 - val_loss: 1.8049 - val_accuracy: 0.6694
# Epoch 7/10
# 213/213 [==============================] - 88s 411ms/step - loss: 0.0493 - accuracy: 0.9893 - val_loss: 2.0075 - val_accuracy: 0.6747
# Epoch 8/10
# 213/213 [==============================] - 105s 493ms/step - loss: 0.0355 - accuracy: 0.9931 - val_loss: 2.0726 - val_accuracy: 0.6724
# Epoch 9/10
# 213/213 [==============================] - 103s 484ms/step - loss: 0.0393 - accuracy: 0.9919 - val_loss: 2.2532 - val_accuracy: 0.6718
# Epoch 10/10
# 213/213 [==============================] - 88s 412ms/step - loss: 0.0520 - accuracy: 0.9869 - val_loss: 2.1875 - val_accuracy: 0.6812

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# As we can see, the performance isn't great, in fact, the model seems to be overfitting the data
# Let's see what we can do to fix that

# %% [markdown]
# ## 6. Data Augmentation and Model Optimization

# %%
# Data Augmentation
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# Visualization of the changes
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
    
# As we can see, the data is now more rich and varied, which should result in a more generalized model

# %%
# Include Dropout in the model
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_5 (Sequential)    (None, 180, 180, 3)       0
# _________________________________________________________________
# rescaling_8 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 30976)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               3965056
# _________________________________________________________________
# dense_13 (Dense)             (None, 11)                1419
# =================================================================
# Total params: 3,990,059
# Trainable params: 3,990,059
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 7. Model Training (Version 2)

# %%
# Train the model again
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 213/213 [==============================] - 91s 422ms/step - loss: 2.3340 - accuracy: 0.1563 - val_loss: 2.2074 - val_accuracy: 0.2135
# Epoch 2/15
# 213/213 [==============================] - 98s 462ms/step - loss: 2.1782 - accuracy: 0.2329 - val_loss: 2.0470 - val_accuracy: 0.2806
# Epoch 3/15
# 213/213 [==============================] - 112s 524ms/step - loss: 2.0050 - accuracy: 0.3110 - val_loss: 1.8916 - val_accuracy: 0.3447
# Epoch 4/15
# 213/213 [==============================] - 112s 525ms/step - loss: 1.8417 - accuracy: 0.3626 - val_loss: 1.7640 - val_accuracy: 0.3959
# Epoch 5/15
# 213/213 [==============================] - 103s 483ms/step - loss: 1.6666 - accuracy: 0.4260 - val_loss: 1.6181 - val_accuracy: 0.4500
# Epoch 6/15
# 213/213 [==============================] - 98s 462ms/step - loss: 1.5361 - accuracy: 0.4796 - val_loss: 1.5732 - val_accuracy: 0.4659
# Epoch 7/15
# 213/213 [==============================] - 93s 436ms/step - loss: 1.4594 - accuracy: 0.5022 - val_loss: 1.5725 - val_accuracy: 0.4765
# Epoch 8/15
# 213/213 [==============================] - 96s 450ms/step - loss: 1.3739 - accuracy: 0.5350 - val_loss: 1.4579 - val_accuracy: 0.5053
# Epoch 9/15
# 213/213 [==============================] - 99s 463ms/step - loss: 1.2946 - accuracy: 0.5566 - val_loss: 1.4745 - val_accuracy: 0.5082
# Epoch 10/15
# 213/213 [==============================] - 97s 454ms/step - loss: 1.2366 - accuracy: 0.5835 - val_loss: 1.5276 - val_accuracy: 0.5224
# Epoch 11/15
# 213/213 [==============================] - 98s 462ms/step - loss: 1.1786 - accuracy: 0.6025 - val_loss: 1.4498 - val_accuracy: 0.5371
# Epoch 12/15
# 213/213 [==============================] - 140s 658ms/step - loss: 1.1488 - accuracy: 0.6118 - val_loss: 1.2903 - val_accuracy: 0.5871
# Epoch 13/15
# 213/213 [==============================] - 114s 535ms/step - loss: 1.0813 - accuracy: 0.6331 - val_loss: 1.4212 - val_accuracy: 0.5712
# Epoch 14/15
# 213/213 [==============================] - 99s 464ms/step - loss: 1.0725 - accuracy: 0.6416 - val_loss: 1.3095 - val_accuracy: 0.5806
# Epoch 15/15
# 213/213 [==============================] - 125s 588ms/step - loss: 1.0263 - accuracy: 0.6632 - val_loss: 1.2118 - val_accuracy: 0.6124

# %%
# Visualize the results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# As we can see, the performance increase is significant. 
# The model is now more generalized and should provide a good performance in most real case scenarios

# %% [markdown]
# ## 8. Predict on new data

# %%
guitar_url = "https://cdn.mos.cms.futurecdn.net/505d6b03064e460e3ee143370fe68b29-1200-80.jpg"

from IPython.display import Image
from IPython.core.display import HTML 
Image(url=guitar_url)
# Out:
# <img src="https://cdn.mos.cms.futurecdn.net/505d6b03064e460e3ee143370fe68b29-1200-80.jpg"/>

# %%
guitar_path = tf.keras.utils.get_file('lp', origin=guitar_url)

img = keras.preprocessing.image.load_img(
    guitar_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
# Out:
# Downloading data from https://cdn.mos.cms.futurecdn.net/505d6b03064e460e3ee143370fe68b29-1200-80.jpg
# 40960/37643 [================================] - 0s 0us/step

# %%
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to gibson_les_paul with a 90.75 percent confidence.

# %% [markdown]
# ## 9. Persist the model

# %%
# Standard persistence
#model.save('guitar_model')
model.save('guitar_model.h5') # H5 format

# %%
# Tensorflow.js persistence
#!tensorflowjs_converter --input_format=keras guitar_model.h5 guitar_model_web
# !tensorflowjs_converter --input_format keras --output_format=tfjs_graph_model guitar_model.h5 guitar_model_web
# Out:
# 2021-07-01 18:25:45.091858: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2021-07-01 18:25:46.072077: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2021-07-01 18:25:47.307400: I tensorflow/core/grappler/devices.cc:78] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# 2021-07-01 18:25:47.307472: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2021-07-01 18:25:47.311858: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 60 nodes (47), 79 edges (66), time = 2.263ms.
#   function_optimizer: function_optimizer did nothing. time = 0.082ms.
#
# 2021-07-01 18:25:47.887705: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   debug_stripper: debug_stripper did nothing. time = 0.009ms.
#   model_pruner: Graph size after: 47 nodes (-13), 66 edges (-13), time = 6.365ms.
#   constant_folding: Graph size after: 37 nodes (-10), 56 edges (-10), time = 79.192ms.
#   arithmetic_optimizer: Graph size after: 37 nodes (0), 56 edges (0), time = 8.969ms.
#   dependency_optimizer: Graph size after: 35 nodes (-2), 34 edges (-22), time = 4.593ms.
#   model_pruner: Graph size after: 35 nodes (0), 34 edges (0), time = 4.323ms.
#   constant_folding: Graph size after: 35 nodes (0), 34 edges (0), time = 21.154ms.
#   arithmetic_optimizer: Graph size after: 35 nodes (0), 34 edges (0), time = 8.833ms.
#   dependency_optimizer: Graph size after: 35 nodes (0), 34 edges (0), time = 4.32ms.
#   debug_stripper: debug_stripper did nothing. time = 1.191ms.
#   model_pruner: Graph size after: 35 nodes (0), 34 edges (0), time = 3.109ms.
#   constant_folding: Graph size after: 35 nodes (0), 34 edges (0), time = 20.699ms.
#   arithmetic_optimizer: Graph size after: 35 nodes (0), 34 edges (0), time = 9.139ms.
#   dependency_optimizer: Graph size after: 35 nodes (0), 34 edges (0), time = 4.358ms.
#   model_pruner: Graph size after: 35 nodes (0), 34 edges (0), time = 4.334ms.
#   constant_folding: Graph size after: 35 nodes (0), 34 edges (0), time = 21.004ms.
#   arithmetic_optimizer: Graph size after: 35 nodes (0), 34 edges (0), time = 9.1ms.
#   dependency_optimizer: Graph size after: 35 nodes (0), 34 edges (0), time = 5.337ms.
#
# 2021-07-01 18:25:48.325701: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   remapper: Graph size after: 26 nodes (-9), 25 edges (-9), time = 23.377ms.
#   constant_folding: Graph size after: 26 nodes (0), 25 edges (0), time = 12.365ms.
#   arithmetic_optimizer: Graph size after: 26 nodes (0), 25 edges (0), time = 6.628ms.
#   dependency_optimizer: Graph size after: 26 nodes (0), 25 edges (0), time = 4.403ms.
#   remapper: Graph size after: 26 nodes (0), 25 edges (0), time = 4.1ms.
#   constant_folding: Graph size after: 26 nodes (0), 25 edges (0), time = 8.81ms.
#   arithmetic_optimizer: Graph size after: 26 nodes (0), 25 edges (0), time = 6.82ms.
#   dependency_optimizer: Graph size after: 26 nodes (0), 25 edges (0), time = 4.44ms.
#
# Writing weight file guitar_model_web/model.json...
